// %%
var a = 12;

// %%
console.log(a);
// Out:
// 12

// %%
$$png$$ = require("fs").readFileSync("skale.png").toString("base64");

// %%
var canvas = new (require("canvas"))(200, 200);
var context = canvas.getContext("2d");

context.arc(100, 100, 100, 0, 2 * Math.PI, false);
context.fill();

$$png$$ = canvas.toBuffer().toString("base64");

// %%
var Canvas = require('canvas')
  , Image = Canvas.Image
  , canvas = new Canvas(200, 200)
  , ctx = canvas.getContext('2d');

//ctx.font = '30px Impact';
ctx.rotate(.4);
ctx.fillText("Awesome!", 50, 100);

var te = ctx.measureText('Awesome!');
ctx.strokeStyle = 'rgba(0,0,0,0.5)';
ctx.beginPath();
ctx.lineTo(50, 102);
ctx.lineTo(50 + te.width, 102);
ctx.stroke();

$$png$$ = canvas.toBuffer().toString('base64')

// %%
var width = 400;
var height = 200;

var robot = require("robotjs");
var Canvas = require('canvas'), Image = Canvas.Image, canvas = new Canvas(width, height) , ctx = canvas.getContext('2d');

var img = robot.screen.capture(0, 0, width, height);

for (var i = 0; i < width; i++) {
    for (var j = 0; j < height; j++) {
        ctx.fillStyle = '#' + img.colorAt(i, j);
        ctx.fillRect(i, j, 1, 1);
    }
}
$$png$$ = canvas.toBuffer().toString('base64');
